# %% [markdown]
# <div style="background: #2c3e50;
#             color: white;
#             padding: 20px;
#             border-radius: 8px;
#             margin: 10px 0;">
#     <h1 style="margin: 0; font-size: 24px;">
#         Étape 1 : Importation des packages
#     </h1>
# </div>

# %%
import pandas as pd
from datetime import datetime
import json
from bs4 import BeautifulSoup
import re

# %% [markdown]
# <div style="background: #2c3e50;
#             color: white;
#             padding: 20px;
#             border-radius: 8px;
#             margin: 10px 0;">
#     <h1 style="margin: 0; font-size: 24px;">
#         Étape 2 : Importation et exploration des données
#     </h1>
# </div>

# %%
df = pd.read_json("../inputs/evenements-publics-openagenda.json")
pd.set_option('display.max_columns', None)
df.head()
# Out:
#         uid                                               slug  \
# 0   7350617          pat-et-mat-un-dernier-tour-de-vis-7459283
# 1  88915442  bibliotheque-de-films-sur-les-metiers-de-lindu...
# 2  75218354  les-cles-pour-entreprendre-par-la-bge-a-france...
# 3  73961640            atelier-bien-etre-parents-bebes-3910479
# 4  40568226                           les-ours-gloutons-604378
#
#                                         canonicalurl  \
# 0  https://openagenda.com/de-la-suite-dans-les-im...
# 1  https://openagenda.com/semaine-industrie-2024/...
# 2  https://openagenda.com/pole-emploi/events/les-...
# 3  https://openagenda.com/coeur-de-flandre-agglo/...
# 4  https://openagenda.com/de-la-suite-dans-les-im...
#
#                                             title_fr  \
# 0                 Pat et Mat, un dernier tour de vis
# 1  Bibliothèque de Films sur les métiers de l'ind...
# 2  LES CLES POUR ENTREPRENDRE PAR LA BGE   A  FRA...
# 3                  Atelier bien-être parents - bébés
# 4                     Les ours gloutons au Pôle Nord
#
#                                       description_fr  \
# 0                  ciné-concert avec Cyrille Aufaure
# 1  Bibliothèque de Films sur les métiers de l'ind...
# 2  Vous souhaitez connaître les démarches pour cr...
# 3  Une action pour le bien-être de l'enfant et de...
# 4                                          ciné-quiz
#
#                                   longdescription_fr    conditions_fr  \
# 0                                               None             None
# 1  <p>La "Bibliothèque de films sur les métiers d...             None
# 2  <p>Vous souhaitez connaître les démarches pour...             None
# 3  <p>Des ateliers où vous massez vous-même votre...  Sur inscription
# 4                                               None             None
#
#                                          keywords_fr  \
# 0                                               None
# 1                                               None
# 2  [Réunion d'information, Création d'entreprise,...
# 3                                               None
# 4                                               None
#
#                                                image imagecredits  \
# 0  https://cdn.openagenda.com/main/9e27503785dc40...         None
# 1                                               None         None
# 2                                               None         None
# 3  https://cdn.openagenda.com/main/ea4c5be5ca3743...         None
# 4  https://cdn.openagenda.com/main/0f4aaeee652642...         None
#
#                                            thumbnail  \
# 0  https://cdn.openagenda.com/main/9e27503785dc40...
# 1                                               None
# 2                                               None
# 3  https://cdn.openagenda.com/main/ea4c5be5ca3743...
# 4  https://cdn.openagenda.com/main/0f4aaeee652642...
#
#                                        originalimage  \
# 0  https://cdn.openagenda.com/main/9e27503785dc40...
# 1                                               None
# 2                                               None
# 3  https://cdn.openagenda.com/main/ea4c5be5ca3743...
# 4  https://cdn.openagenda.com/main/0f4aaeee652642...
#
#                    updatedat                     daterange_fr  \
# 0  2025-01-29T16:22:11+00:00          Mardi 18 février, 10h00
# 1  2025-01-15T01:11:10+00:00  Mercredi 4 décembre 2024, 08h00
# 2  2024-03-18T11:10:41+00:00       Mercredi 4 décembre, 09h30
# 3  2024-12-31T11:12:42+00:00               28 mars et 4 avril
# 4  2024-11-26T06:19:45+00:00    Jeudi 26 décembre 2024, 15h00
#
#              firstdate_begin              firstdate_end  \
# 0  2025-02-18T09:00:00+00:00  2025-02-18T11:00:00+00:00
# 1  2024-12-04T07:00:00+00:00  2024-12-04T11:00:00+00:00
# 2  2024-12-04T08:30:00+00:00  2024-12-04T10:30:00+00:00
# 3  2025-03-28T13:00:00+00:00  2025-03-28T15:00:00+00:00
# 4  2024-12-26T14:00:00+00:00  2024-12-26T16:00:00+00:00
#
#               lastdate_begin               lastdate_end  \
# 0  2025-02-18T09:00:00+00:00  2025-02-18T11:00:00+00:00
# 1  2024-12-04T07:00:00+00:00  2024-12-04T11:00:00+00:00
# 2  2024-12-04T08:30:00+00:00  2024-12-04T10:30:00+00:00
# 3  2025-04-04T12:00:00+00:00  2025-04-04T14:00:00+00:00
# 4  2024-12-26T14:00:00+00:00  2024-12-26T16:00:00+00:00
#
#                                              timings accessibility  \
# 0  [{"begin": "2025-02-18T10:00:00+01:00", "end":...          None
# 1  [{"begin": "2024-12-04T08:00:00+01:00", "end":...          None
# 2  [{"begin": "2024-12-04T09:30:00+01:00", "end":...          None
# 3  [{"begin": "2025-03-28T14:00:00+01:00", "end":...          None
# 4  [{"begin": "2024-12-26T15:00:00+01:00", "end":...          None
#
#   accessibility_label_fr  location_uid                 location_coordinates  \
# 0                   None      16626027  {'lon': 2.636271, 'lat': 50.640565}
# 1                   None      47482976  {'lon': 3.051628, 'lat': 50.617823}
# 2                   None      79935918  {'lon': 2.110436, 'lat': 49.277206}
# 3                   None      30200063  {'lon': 2.487499, 'lat': 50.799598}
# 4                   None      48753397  {'lon': 3.154677, 'lat': 50.700052}
#
#                     location_name                          location_address  \
# 0  Espace culturel Robert Hossein  19 Rue du Pont de Pierre, 59660 Merville
# 1             Cité Marianne Lille           2 boulevard de strasbourg Lille
# 2                            Méru                                60110 Méru
# 3                   Centre Social                        CASSEL grand-place
# 4               Cinéma du Fresnoy        22 Rue du Fresnoy, 59200 Tourcoing
#
#   location_district  location_insee  location_postalcode location_city  \
# 0              None         59400.0              59660.0      Merville
# 1     Lille-Moulins         59350.0              59000.0         Lille
# 2              None         60162.0              60110.0  Corbeil-Cerf
# 3              None         59135.0              59670.0        Cassel
# 4              None         59599.0              59200.0     Tourcoing
#
#   location_department  location_region location_countrycode location_image  \
# 0                Nord  Hauts-de-France                   FR           None
# 1                Nord  Hauts-de-France                   FR           None
# 2                Oise  Hauts-de-France                   FR           None
# 3                Nord  Hauts-de-France                   FR           None
# 4                Nord  Hauts-de-France                   FR           None
#
#   location_imagecredits location_phone             location_website  \
# 0                  None           None  https://culturemerville.fr/
# 1                  None           None                         None
# 2                  None           None                         None
# 3                  None           None                         None
# 4                  None           None   https://www.lefresnoy.net/
#
#   location_links location_tags location_description_fr location_access_fr  \
# 0           None          None                    None               None
# 1           None          None                    None               None
# 2           None          None                    None               None
# 3           None          None                    None               None
# 4           None          None                    None               None
#
#                                       attendancemode  \
# 0  {"id": 1, "label": {"fr": "Sur place", "en": "...
# 1  {"id": 2, "label": {"fr": "En ligne", "en": "O...
# 2  {"id": 1, "label": {"fr": "Sur place", "en": "...
# 3  {"id": 1, "label": {"fr": "Sur place", "en": "...
# 4  {"id": 1, "label": {"fr": "Sur place", "en": "...
#
#                                     onlineaccesslink  \
# 0                                               None
# 1  https://hauts-de-france.dreets.gouv.fr/La-Bibl...
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                               status  age_min  age_max  \
# 0  {"id": 1, "label": {"fr": "Programm\u00e9", "e...      NaN      NaN
# 1  {"id": 1, "label": {"fr": "Programm\u00e9", "e...      NaN      NaN
# 2  {"id": 1, "label": {"fr": "Programm\u00e9", "e...      NaN      NaN
# 3  {"id": 1, "label": {"fr": "Programm\u00e9", "e...      NaN      NaN
# 4  {"id": 1, "label": {"fr": "Programm\u00e9", "e...      NaN      NaN
#
#             originagenda_title  originagenda_uid  contributor_email  \
# 0  De la suite dans les images           6821494                NaN
# 1  Semaine de l'industrie 2024          79099130                NaN
# 2   Mes événements Pôle Emploi          38495884                NaN
# 3        Cœur de Flandre agglo          68189472                NaN
# 4  De la suite dans les images           6821494                NaN
#
#    contributor_contactnumber  contributor_contactname  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
#
#    contributor_contactposition  contributor_organization  category  \
# 0                          NaN                       NaN       NaN
# 1                          NaN                       NaN       NaN
# 2                          NaN                       NaN       NaN
# 3                          NaN                       NaN       NaN
# 4                          NaN                       NaN       NaN
#
#            country_fr                                       registration links
# 0  France (Métropole)                                               None  None
# 1  France (Métropole)  [{"type": "email", "value": "dreets-hdf.semain...  None
# 2  France (Métropole)  [{"type": "link", "value": "https://meseveneme...  None
# 3  France (Métropole)  [{"type": "phone", "value": "03 59 73 48 30"},...  None
# 4  France (Métropole)                                               None  None

# %% [markdown]
# <div style="background: #3498db; color: white; padding: 1rem 2rem; border-radius: 5px;">
#     <p style="margin: 0;">
#         Le dataset contenant un grand nombre de lignes et de colonnes, nous commencerons par sélectionner les variables pertinentes pour le chatbot avant d'analyser le taux de valeurs manquantes.
#     </p>
# </div>

# %% [markdown]
# <div style="background: #27ae60; color: white; padding: 1rem 2rem; border-radius: 5px;">
#     <p style="margin: 0;">
#     Quelles sont les colonnes disponibles ?    </p>
# </div>

# %%
missing_df = (
    df.isna()
      .mean()
      .mul(100)
      .round(2)
      .reset_index()
      .rename(columns={"index": "colonne", 0: "valeur manquante"})
)

print(missing_df)
# Out:
#                         colonne  valeur manquante
# 0                           uid              0.00
# 1                          slug              0.00
# 2                  canonicalurl              0.00
# 3                      title_fr              0.02
# 4                description_fr              0.02
# 5            longdescription_fr              3.81
# 6                 conditions_fr             47.87
# 7                   keywords_fr             73.87
# 8                         image             10.09
# 9                  imagecredits             31.94
# 10                    thumbnail             10.24
# 11                originalimage             10.24
# 12                    updatedat              0.00
# 13                 daterange_fr              0.00
# 14              firstdate_begin              0.00
# 15                firstdate_end              0.00
# 16               lastdate_begin              0.00
# 17                 lastdate_end              0.00
# 18                      timings              0.00
# 19                accessibility             81.51
# 20       accessibility_label_fr             81.51
# 21                 location_uid              0.00
# 22         location_coordinates              0.49
# 23                location_name              0.00
# 24             location_address              0.00
# 25            location_district             73.24
# 26               location_insee              4.94
# 27          location_postalcode              0.92
# 28                location_city              0.00
# 29          location_department              0.00
# 30              location_region              0.00
# 31         location_countrycode              0.00
# 32               location_image             68.67
# 33        location_imagecredits             71.80
# 34               location_phone             64.65
# 35             location_website             67.90
# 36               location_links             85.66
# 37                location_tags             62.91
# 38      location_description_fr             67.86
# 39           location_access_fr             78.54
# 40               attendancemode              0.00
# 41             onlineaccesslink             98.57
# 42                       status              0.00
# 43                      age_min             90.32
# 44                      age_max             86.17
# 45           originagenda_title              0.00
# 46             originagenda_uid              0.00
# 47            contributor_email            100.00
# 48    contributor_contactnumber            100.00
# 49      contributor_contactname            100.00
# 50  contributor_contactposition            100.00
# 51     contributor_organization            100.00
# 52                     category            100.00
# 53                   country_fr              0.00
# 54                 registration             60.07
# 55                        links             89.48

# %% [markdown]
# <div style="background: #3498db; color: white; padding: 1rem 2rem; border-radius: 5px;">
#     <p style="margin: 0 0 0.75rem 0; font-weight: 600;">
#         Nous avons pas mal de colonnes, mais certaines sont plus importantes que d'autres :
#     </p>
#     <ul style="margin: 0; padding-left: 1.2rem;">
#         <li>title_fr</li>
#         <li>description_fr</code></li>
#         <li>longdescription_fr</code></li>
#         <li>conditions_fr</code></li>
#         <li>timings</code></li>
#         <li>location_name</code></li>
#         <li>location_address</code></li>
#         <li>location_insee</code></li>
#         <li>location_postalcode</code></li>
#         <li>location_city</code></li>
#         <li>location_department</code></li>
#         <li>location_region</code></li>
#         <li>location_countrycode</code></li>
#         <li>age_min</code></li>
#         <li>age_max</code></li>
#         <li>registration</code></li>
#     </ul>
# </div>

# %%
column_keep = [
    "title_fr",
    "description_fr",
    "longdescription_fr",
    "conditions_fr",
    "timings",
    "location_name",
    "location_address",
    "location_insee",
    "location_postalcode",
    "location_city",
    "location_department",
    "location_region",
    "location_countrycode",
    "age_min",
    "age_max",
    "registration",
    "location_phone",          
    "location_website"
]

# %%
df = df[column_keep]
df.head()
# Out:
#                                             title_fr  \
# 0                 Pat et Mat, un dernier tour de vis
# 1  Bibliothèque de Films sur les métiers de l'ind...
# 2  LES CLES POUR ENTREPRENDRE PAR LA BGE   A  FRA...
# 3                  Atelier bien-être parents - bébés
# 4                     Les ours gloutons au Pôle Nord
#
#                                       description_fr  \
# 0                  ciné-concert avec Cyrille Aufaure
# 1  Bibliothèque de Films sur les métiers de l'ind...
# 2  Vous souhaitez connaître les démarches pour cr...
# 3  Une action pour le bien-être de l'enfant et de...
# 4                                          ciné-quiz
#
#                                   longdescription_fr    conditions_fr  \
# 0                                               None             None
# 1  <p>La "Bibliothèque de films sur les métiers d...             None
# 2  <p>Vous souhaitez connaître les démarches pour...             None
# 3  <p>Des ateliers où vous massez vous-même votre...  Sur inscription
# 4                                               None             None
#
#                                              timings  \
# 0  [{"begin": "2025-02-18T10:00:00+01:00", "end":...
# 1  [{"begin": "2024-12-04T08:00:00+01:00", "end":...
# 2  [{"begin": "2024-12-04T09:30:00+01:00", "end":...
# 3  [{"begin": "2025-03-28T14:00:00+01:00", "end":...
# 4  [{"begin": "2024-12-26T15:00:00+01:00", "end":...
#
#                     location_name                          location_address  \
# 0  Espace culturel Robert Hossein  19 Rue du Pont de Pierre, 59660 Merville
# 1             Cité Marianne Lille           2 boulevard de strasbourg Lille
# 2                            Méru                                60110 Méru
# 3                   Centre Social                        CASSEL grand-place
# 4               Cinéma du Fresnoy        22 Rue du Fresnoy, 59200 Tourcoing
#
#    location_insee  location_postalcode location_city location_department  \
# 0         59400.0              59660.0      Merville                Nord
# 1         59350.0              59000.0         Lille                Nord
# 2         60162.0              60110.0  Corbeil-Cerf                Oise
# 3         59135.0              59670.0        Cassel                Nord
# 4         59599.0              59200.0     Tourcoing                Nord
#
#    location_region location_countrycode  age_min  age_max  \
# 0  Hauts-de-France                   FR      NaN      NaN
# 1  Hauts-de-France                   FR      NaN      NaN
# 2  Hauts-de-France                   FR      NaN      NaN
# 3  Hauts-de-France                   FR      NaN      NaN
# 4  Hauts-de-France                   FR      NaN      NaN
#
#                                         registration location_phone  \
# 0                                               None           None
# 1  [{"type": "email", "value": "dreets-hdf.semain...           None
# 2  [{"type": "link", "value": "https://meseveneme...           None
# 3  [{"type": "phone", "value": "03 59 73 48 30"},...           None
# 4                                               None           None
#
#               location_website
# 0  https://culturemerville.fr/
# 1                         None
# 2                         None
# 3                         None
# 4   https://www.lefresnoy.net/

# %% [markdown]
# <div style="background: #2c3e50;
#             color: white;
#             padding: 20px;
#             border-radius: 8px;
#             margin: 10px 0;">
#     <h1 style="margin: 0; font-size: 24px;">
#         Étape 3 : Nettoyage des données
#     </h1>
# </div>

# %%
print(f"Nombre d'événements avant le nettoyage sur les valeurs indispenssable : {len(df)}")

df = df[
    (df['title_fr'].notnull()) & 
    (df['location_address'].notnull()) &
    (df['description_fr'].notnull()) &
    (df['timings'].notnull())
]

print(f"Nombre d'événements après le nettoyage : {len(df)}")
# Out:
# Nombre d'événements avant le nettoyage sur les valeurs indispenssable : 6096
# Nombre d'événements après le nettoyage : 6095

# %%
# Format Age / location_insee / location_postalcode en int
df['location_insee'] = df['location_insee'].astype('Int64')
df['location_postalcode'] = df['location_postalcode'].astype('Int64')
df['age_min'] = df['age_min'].astype('Int64')
df['age_max'] = df['age_max'].astype('Int64')

df['location_phone'] = df['location_phone'].fillna("pas de numéro de téléphone")
df['location_website'] = df['location_website'].fillna("pas de site")

print(df[['location_insee', 'location_postalcode','age_min', 'age_max', 'location_website', 'location_phone']].head())
# Out:
#    location_insee  location_postalcode  age_min  age_max  \
# 0           59400                59660     <NA>     <NA>
# 1           59350                59000     <NA>     <NA>
# 2           60162                60110     <NA>     <NA>
# 3           59135                59670     <NA>     <NA>
# 4           59599                59200     <NA>     <NA>
#
#               location_website              location_phone
# 0  https://culturemerville.fr/  pas de numéro de téléphone
# 1                  pas de site  pas de numéro de téléphone
# 2                  pas de site  pas de numéro de téléphone
# 3                  pas de site  pas de numéro de téléphone
# 4   https://www.lefresnoy.net/  pas de numéro de téléphone

# %%
df['conditions_fr'] = df['conditions_fr'].fillna("Aucune condition précisée")
df['registration'] = df['registration'].fillna("Pas de lien d'inscription")
print(df[['registration', 'conditions_fr']].head())
# Out:
#                                         registration  \
# 0                          Pas de lien d'inscription
# 1  [{"type": "email", "value": "dreets-hdf.semain...
# 2  [{"type": "link", "value": "https://meseveneme...
# 3  [{"type": "phone", "value": "03 59 73 48 30"},...
# 4                          Pas de lien d'inscription
#
#                conditions_fr
# 0  Aucune condition précisée
# 1  Aucune condition précisée
# 2  Aucune condition précisée
# 3            Sur inscription
# 4  Aucune condition précisée

# %%
# Nettoyer l'HTML

def remove_html(text):
    if not text or str(text) == 'nan':
        return ""
        
    text_no_html = BeautifulSoup(text, "html.parser").get_text(separator=" ")
    text_clean = re.sub(r'\s+', ' ', text_no_html)
    return text_clean.strip()

df['longdescription_fr' ] = df['longdescription_fr' ].apply(remove_html)

print(df[['longdescription_fr']].head())
# Out:
#                                   longdescription_fr
# 0
# 1  La "Bibliothèque de films sur les métiers de l...
# 2  Vous souhaitez connaître les démarches pour cr...
# 3  Des ateliers où vous massez vous-même votre bé...
# 4

# %%
# Nettoyer inscription

def clean_registration(value):
    if not value or str(value) == 'nan':
        return "Entrée libre"
        
    try:
        reg_list = json.loads(value)
        
        infos_contact = []
        
        for item in reg_list:
            type_contact = item.get('type')
            valeur_contact = item.get('value')
            
            if type_contact == 'phone':
                infos_contact.append(f"phone: {valeur_contact}")
            elif type_contact == 'email':
                infos_contact.append(f"email: {valeur_contact}")
            elif type_contact == 'link':
                infos_contact.append(f"link: {valeur_contact}")
            else:
                infos_contact.append(valeur_contact)
        
        if not infos_contact:
            return "Voir description"
            
        return " | ".join(infos_contact)
        
    except Exception:
        return "Voir description"



df['registration'] = df['registration'].apply(clean_registration)

# %%
# Nettoyer timing

def clean_timings(value):
    if not value or str(value) == 'nan':
        return "Horaires non précisés"
    
    try:
        timings_list = json.loads(value)
        
        readable_dates = []
        for t in timings_list:
            start = datetime.fromisoformat(t['begin'])
            end = datetime.fromisoformat(t['end'])
            
            date_str = start.strftime("%d/%m/%Y")
            start_hour = start.strftime("%H:%M")
            end_hour = end.strftime("%H:%M")
            
            readable_dates.append(f"Le {date_str} de {start_hour} à {end_hour}")
            
        return " / ".join(readable_dates)
        
    except (json.JSONDecodeError, ValueError, TypeError):
        return "Horaires invalides"
        
df['timings'] = df['timings'].apply(clean_timings)

# %%
df.head(10)
# Out:
#                                             title_fr  \
# 0                 Pat et Mat, un dernier tour de vis
# 1  Bibliothèque de Films sur les métiers de l'ind...
# 2  LES CLES POUR ENTREPRENDRE PAR LA BGE   A  FRA...
# 3                  Atelier bien-être parents - bébés
# 4                     Les ours gloutons au Pôle Nord
# 5  Présentation du Titre professionnel réceptionn...
# 6  Atelier Modelage de bougies - au Labo de Cambr...
# 7  A la découverte du monde de l'industrie - Ouve...
# 8  Rejoignez La Chicorée : Job Dating pour Cuisin...
# 9                                    Mon inséparable
#
#                                       description_fr  \
# 0                  ciné-concert avec Cyrille Aufaure
# 1  Bibliothèque de Films sur les métiers de l'ind...
# 2  Vous souhaitez connaître les démarches pour cr...
# 3  Une action pour le bien-être de l'enfant et de...
# 4                                          ciné-quiz
# 5  Dans le cadre de la semaine du tourisme, l'AFP...
# 6                           📆 Jeudi 26 décembre 2024
# 7  Venez découvrir le monde de l'industrie automo...
# 8  Participez à notre job dating exclusif organis...
# 9         rencontre avec la comédienne Rébecca Finet
#
#                                   longdescription_fr  \
# 0
# 1  La "Bibliothèque de films sur les métiers de l...
# 2  Vous souhaitez connaître les démarches pour cr...
# 3  Des ateliers où vous massez vous-même votre bé...
# 4
# 5  Dans le cadre de la semaine du tourisme, l'AFP...
# 6  Viens créer une bougie personnalisée du bout d...
# 7  Vous souhaitez découvrir l'industrie automobil...
# 8  Participez à notre job dating exclusif organis...
# 9
#
#                conditions_fr  \
# 0  Aucune condition précisée
# 1  Aucune condition précisée
# 2  Aucune condition précisée
# 3            Sur inscription
# 4  Aucune condition précisée
# 5  Aucune condition précisée
# 6  Aucune condition précisée
# 7  Aucune condition précisée
# 8  Aucune condition précisée
# 9  Aucune condition précisée
#
#                                              timings  \
# 0                     Le 18/02/2025 de 10:00 à 12:00
# 1                     Le 04/12/2024 de 08:00 à 12:00
# 2                     Le 04/12/2024 de 09:30 à 11:30
# 3  Le 28/03/2025 de 14:00 à 16:00 / Le 04/04/2025...
# 4                     Le 26/12/2024 de 15:00 à 17:00
# 5                     Le 19/03/2025 de 14:00 à 16:00
# 6                     Le 26/12/2024 de 15:00 à 16:00
# 7                     Le 03/12/2024 de 10:00 à 15:30
# 8                     Le 06/03/2025 de 14:00 à 14:30
# 9                     Le 19/01/2025 de 18:00 à 21:00
#
#                     location_name                          location_address  \
# 0  Espace culturel Robert Hossein  19 Rue du Pont de Pierre, 59660 Merville
# 1             Cité Marianne Lille           2 boulevard de strasbourg Lille
# 2                            Méru                                60110 Méru
# 3                   Centre Social                        CASSEL grand-place
# 4               Cinéma du Fresnoy        22 Rue du Fresnoy, 59200 Tourcoing
# 5                          Seclin                              59113 Seclin
# 6                         Le Labo         2 Rue Louis Renard, 59400 Cambrai
# 7           Valeo Electrification     Route d'Hilbert 62630 Etaples-sur-mer
# 8                           Lille                               59800 Lille
# 9  Espace culturel Robert Hossein  19 Rue du Pont de Pierre, 59660 Merville
#
#    location_insee  location_postalcode location_city location_department  \
# 0           59400                59660      Merville                Nord
# 1           59350                59000         Lille                Nord
# 2           60162                60110  Corbeil-Cerf                Oise
# 3           59135                59670        Cassel                Nord
# 4           59599                59200     Tourcoing                Nord
# 5            <NA>                59113        Seclin                Nord
# 6           59122                59400       Cambrai                Nord
# 7           62318                62630       Étaples       Pas-de-Calais
# 8           59350                59800         Lille                Nord
# 9           59400                59660      Merville                Nord
#
#    location_region location_countrycode  age_min  age_max  \
# 0  Hauts-de-France                   FR     <NA>     <NA>
# 1  Hauts-de-France                   FR     <NA>     <NA>
# 2  Hauts-de-France                   FR     <NA>     <NA>
# 3  Hauts-de-France                   FR     <NA>     <NA>
# 4  Hauts-de-France                   FR     <NA>     <NA>
# 5  Hauts-de-France                   FR     <NA>     <NA>
# 6  Hauts-de-France                   FR     <NA>     <NA>
# 7  Hauts-de-France                   FR     <NA>     <NA>
# 8  Hauts-de-France                   FR     <NA>     <NA>
# 9  Hauts-de-France                   FR     <NA>     <NA>
#
#                                         registration  \
# 0                                   Voir description
# 1  email: dreets-hdf.semaine-industrie@dreets.gou...
# 2  link: https://mesevenementsemploi.pole-emploi....
# 3  phone: 03 59 73 48 30 | email: pmi-hazebrouck@...
# 4                                   Voir description
# 5  link: https://mesevenementsemploi.francetravai...
# 6                                   Voir description
# 7                   email: melanie.mionnet@valeo.com
# 8  link: https://mesevenementsemploi.francetravai...
# 9                                   Voir description
#
#                location_phone             location_website
# 0  pas de numéro de téléphone  https://culturemerville.fr/
# 1  pas de numéro de téléphone                  pas de site
# 2  pas de numéro de téléphone                  pas de site
# 3  pas de numéro de téléphone                  pas de site
# 4  pas de numéro de téléphone   https://www.lefresnoy.net/
# 5  pas de numéro de téléphone                  pas de site
# 6  pas de numéro de téléphone                  pas de site
# 7  pas de numéro de téléphone                  pas de site
# 8  pas de numéro de téléphone                  pas de site
# 9  pas de numéro de téléphone  https://culturemerville.fr/

# %% [markdown]
# <div style="background: #2c3e50;
#             color: white;
#             padding: 20px;
#             border-radius: 8px;
#             margin: 10px 0;">
#     <h1 style="margin: 0; font-size: 24px;">
#         Étape 4 : Exportation des données après nettoyage
#     </h1>
# </div>

# %%
data_list = df.to_dict(orient='records')

with open("../outputs/evenements-publics-openagenda-clean.json", 'w', encoding='utf-8') as f: 
    json.dump( data_list, f, ensure_ascii=False,indent=4)

print(f"Fichier nettoyé et sauvegardé dans 'outputs/evenements-publics-openagenda-clean.json'")
# Out:
# Fichier nettoyé et sauvegardé dans 'outputs/evenements-publics-openagenda-clean.json'
